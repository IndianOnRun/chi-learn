# %%
import imp

munge = imp.load_source('munge', '../clearn/munge.py')

# %%
master_dict = munge.get_master_dict('../data/crimeSample.csv')
# Out:
# ../clearn/munge.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data_frame['Community Area'] = data_frame['Community Area'].map(lambda num: str(int(num)))
# ../clearn/munge.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data_frame[col_name] = data_frame[col_name].map(lambda unbinned: unbinned_to_binned[unbinned])
# ../clearn/munge.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
len(master_dict)
# Out:
# 78

# %%
master_dict['Edgewater'][:5]
# Out:
#             Arrest  Domestic  Violent Crimes  Severe Crimes  Minor Crimes  \
# Date
# 2014-09-28       0         0               0              3             0
# 2014-09-29       0         1               1              2             0
# 2014-09-30       0         0               0              4             0
# 2014-10-01       1         2               1              1             0
# 2014-10-02       1         2               2              1             1
#
#             Petty Crimes Violent Crime Committed? Month Weekday
# Date
# 2014-09-28             0                    False     9       6
# 2014-09-29             0                     True     9       0
# 2014-09-30             0                    False     9       1
# 2014-10-01             2                     True    10       2
# 2014-10-02             1                     True    10       3

# %%
import datetime

# %%
my_day = datetime.date(2014, 9, 29)

# %%
my_day
# Out:
# datetime.date(2014, 9, 29)

# %%
len(master_dict['Kenwood'])
# Out:
# 167

# %%
master_dict['Edgewater'].loc[:my_day][:-1]
# Out:
#             Arrest  Domestic  Violent Crimes  Severe Crimes  Minor Crimes  \
# Date
# 2014-09-28       0         0               0              3             0
#
#             Petty Crimes Violent Crime Committed? Month Weekday
# Date
# 2014-09-28             0                    False     9       6

# %%
res = (master_dict['Edgewater'].loc[my_day]['Violent Crime Committed?'])

# %%
res?

# %%
range_test_day = datetime.datetime(2014, 10, 30)

# %%
thirty_days = datetime.timedelta(days=30)

# %%
thirty_days_ago = range_test_day - thirty_days

# %%
master_dict['Edgewater'].loc[thirty_days_ago : range_test_day]
# Out:
#             Arrest  Domestic  Violent Crimes  Severe Crimes  Minor Crimes  \
# Date
# 2014-09-30       0         0               0              4             0
# 2014-10-01       1         2               1              1             0
# 2014-10-02       1         2               2              1             1
# 2014-10-03       0         0               1              4             1
# 2014-10-04       2         1               0              3             0
# 2014-10-05       0         0               2              3             0
# 2014-10-06       1         0               0              2             0
# 2014-10-07       2         0               1              2             1
# 2014-10-08       2         0               3              3             0
# 2014-10-09       0         0               1              0             2
# 2014-10-10       3         0               0              3             3
# 2014-10-11       3         1               1              5             2
# ...
