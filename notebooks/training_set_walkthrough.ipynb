# %%
import pandas as pd
import csv

# %%
data_frame = pd.read_csv('../data/Crimes_-_2001_to_present.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:1164: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
def make_clean_timestamps(data_frame):
    data_frame = drop_all_columns_but(data_frame, ['Date', 'Primary Type', 'Community Area', 'Arrest', 'Domestic'])
    data_frame = convert_comm_area_nums_to_names(data_frame)
    data_frame = transform_from_csv(data_frame, 'Primary Type', '../config/crime_bins.csv')
    timestamps = reindex_by_date(data_frame)
    timestamps = make_cols_categorical(timestamps, ['Primary Type', 'Community Area'])
    return timestamps


def drop_all_columns_but(data_frame, columns):
    return data_frame.reindex(columns=columns)


def convert_comm_area_nums_to_names(data_frame):
    # Replace floats with ints. If no translation, mark it as 0 (an invalid community number)
    def clean_comm_area_value(val):
        try:
            return int(val)
        except ValueError:
            return 0
    data_frame['Community Area'] = data_frame['Community Area'].map(clean_comm_area_value)
    # Remove rows with invalid community area numbers
    data_frame = data_frame[data_frame['Community Area'] > 0]
    # Convert numbers to strings for easy binning
    data_frame['Community Area'] = data_frame['Community Area'].map(lambda num: str(int(num)))
    data_frame = transform_from_csv(data_frame, 'Community Area', '../config/community_areas.csv')
    return data_frame


def transform_from_csv(data_frame, col_name, csv_name):
    with open(csv_name, 'rb') as bin_file:
        unbinned_to_binned = {}
        reader = csv.reader(bin_file)
        for line in reader:
            unbinned_to_binned[line[0]] = line[1]

    data_frame[col_name] = data_frame[col_name].map(lambda unbinned: unbinned_to_binned[unbinned])
    return data_frame


def reindex_by_date(data_frame):
    data_frame.index = pd.to_datetime(data_frame['Date'])
    return data_frame.drop('Date', 1)


def make_cols_categorical(data_frame, col_names):
    for name in col_names:
        data_frame[name] = data_frame[name].astype('category')
    return data_frame

# %%
timestamps = make_clean_timestamps(data_frame)
len(timestamps)
# Out:
# 9999

# %%
timestamps
# Out:
#                     Primary Type          Community Area Arrest Domestic
# Date
# 2015-03-13 23:56:00      Violent         Lower West Side  False    False
# 2015-03-13 23:56:00        Petty          Jefferson Park   True    False
# 2015-03-13 23:52:00       Severe      West Garfield park  False    False
# 2015-03-13 23:50:00      Violent                 Kenwood  False     True
# 2015-03-13 23:48:00        Minor                 Hermosa  False    False
# 2015-03-13 23:45:00       Severe             Irving Park  False    False
# 2015-03-13 23:45:00        Petty          West Englewood   True    False
# 2015-03-13 23:45:00      Violent             Rogers Park  False    False
# 2015-03-13 23:45:00      Violent            Chicago Lawn   True     True
# 2015-03-13 23:44:00      Violent            West Pullman  False    False
# 2015-03-13 23:40:00      Violent                 Kenwood  False    False
# 2015-03-13 23:40:00        Petty      West Garfield park   True    False
# 2015-03-13 23:38:00        Petty            Logan Square   True    False
# 2015-03-13 23:35:00        Petty           Humboldt Park   True    False
# 2015-03-13 23:30:00      Violent           South Chicago   True     True
# 2015-03-13 23:30:00      Violent          North Lawndale   True    False
# 2015-03-13 23:30:00       Severe                    Loop  False    False
# 2015-03-13 23:30:00        Petty                Clearing   True    False
# 2015-03-13 23:30:00       Severe           Humboldt Park  False    False
# 2015-03-13 23:30:00        Petty           Humboldt Park   True    False
# 2015-03-13 23:23:00       Severe                  Austin  False    False
# 2015-03-13 23:20:00        Petty          West Englewood   True    False
# 2015-03-13 23:20:00        Petty               Englewood   True    False
# 2015-03-13 23:20:00        Petty          South Lawndale   True    False
# 2015-03-13 23:20:00       Severe                  Austin   True    False
# 2015-03-13 23:10:00      Violent               Hegewisch  False     True
# 2015-03-13 23:10:00       Severe                  Austin  False    False
# 2015-03-13 23:00:00       Severe                  Austin  False    False
# 2015-03-13 23:00:00      Violent               Englewood  False    False
# 2015-03-13 23:00:00        Petty             South Shore  False     True
# ...                          ...                     ...    ...      ...
# 2015-02-26 07:15:00       Severe         Near North Side  False    False
# 2015-02-26 07:00:00       Severe            Norwood Park  False    False
# 2015-02-26 07:00:00       Severe                 Douglas  False    False
# 2015-02-26 07:00:00       Severe           Humboldt Park  False    False
# 2015-02-26 07:00:00       Severe           South Chicago  False    False
# 2015-02-26 07:00:00       Severe                    Loop  False    False
# 2015-02-26 07:00:00       Severe                Roseland  False    False
# 2015-02-26 06:50:00      Violent  Greater Grand Crossing  False    False
# 2015-02-26 06:30:00        Minor              Bridgeport   True    False
# 2015-02-26 06:30:00       Severe          Near West Side  False    False
# 2015-02-26 06:17:00        Minor             Rogers Park  False    False
# 2015-02-26 06:00:00      Violent      Washington Heights  False     True
# 2015-02-26 06:00:00       Severe  Greater Grand Crossing  False    False
# 2015-02-26 05:40:00       Severe                 Chatham  False    False
# 2015-02-26 05:28:00       Severe  Greater Grand Crossing  False    False
# 2015-02-26 05:20:00       Severe               Englewood  False    False
# 2015-02-26 05:05:00        Petty                  O'Hare   True    False
# 2015-02-26 05:01:00      Violent                  Austin   True    False
# 2015-02-26 05:00:00       Severe              North Park  False    False
# 2015-02-26 04:45:00       Severe             Fuller Park  False    False
# 2015-02-26 04:45:00        Minor               Lake View  False    False
# 2015-02-26 04:40:00       Severe             Albany Park  False    False
# 2015-02-26 04:30:00       Severe          West Englewood  False    False
# 2015-02-26 04:02:00        Minor      Washington Heights   True    False
# 2015-02-26 04:00:00      Violent           McKinley Park  False    False
# 2015-02-26 04:00:00      Violent                  Austin  False     True
# 2015-02-26 03:55:00       Severe         Grand Boulevard  False    False
# 2015-02-26 03:00:00       Severe           Humboldt Park  False    False
# 2015-02-26 03:00:00       Severe                  Uptown  False    False
# 2015-02-26 02:48:00       Severe                 Kenwood  False    False
#
# [9999 rows x 4 columns]

# %%
def make_target_vectors(timestamps):
    timestamps = timestamps[timestamps['Primary Type'] == 'Violent']
    # Add a new column that we'll use to sum crimes per day
    timestamps['Violent Crime'] = 1
    grouped = timestamps.groupby('Community Area')
    targets = {}
    for name, frame in grouped:
        # Make one row per day
        area_crimes = frame.resample('D', how='sum')
        # Create new column that is true iff at least one violent crime was committed that day
        area_crimes['Violent Crime Committed'] = area_crimes['Violent Crime'].map(lambda num_crimes: num_crimes > 0)
        # Store the raw True/False values in the target vector
        targets[name] = area_crimes['Violent Crime Committed'].values
    return targets

# %%
targets = make_target_vectors(timestamps)
# Out:
# -c:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
targets['Edgewater'][:5]
# Out:
# array([ True,  True, False, False, False], dtype=bool)

# %%
def make_series_of_days_from_timestamps(timestamps, include_time_features=False):
    timestamps = extract_severity_counts(timestamps)
    days = resample_by_day(timestamps)
    if include_time_features:
        days = extract_time_features(days)
    days = extract_windows(days)
    return days


def extract_severity_counts(timestamps):
    for label in ['Violent', 'Severe', 'Minor', 'Petty']:
        timestamps[label + ' Crimes'] = [int(classification == label) for classification in timestamps['Primary Type']]
    return timestamps


def resample_by_day(timestamps):
    days = timestamps.resample('D', how='sum')
    return days


def extract_time_features(days):
    days['Month'] = days.index.map(lambda stamp: stamp.month)
    days['Weekday'] = days.index.map(lambda stamp: stamp.weekday())
    days = make_cols_categorical(days, ['Month', 'Weekday'])
    return days


def extract_windows(days):
    for label in ['Violent', 'Severe', 'Minor', 'Petty']:
        days[label + ' Crimes in Last Week'] = pd.rolling_sum(days[label + ' Crimes'], 7)
        days[label + ' Crimes in Last Month'] = pd.rolling_sum(days[label + ' Crimes'], 30)
    return days

# %%
days_pan_city = make_series_of_days_from_timestamps(timestamps)

# %%
days_pan_city[-5:]
# Out:
#             Arrest  Domestic  Violent Crimes  Severe Crimes  Minor Crimes  \
# Date
# 2015-03-09     192       107             203            270            68
# 2015-03-10     188       108             187            288            73
# 2015-03-11     196        92             177            295            74
# 2015-03-12     219       106             205            275            77
# 2015-03-13     198       103             201            332            75
#
#             Petty Crimes  Violent Crimes in Last Week  \
# Date
# 2015-03-09           139                         1211
# 2015-03-10           153                         1236
# 2015-03-11           146                         1246
# 2015-03-12           148                         1294
# 2015-03-13           142                         1343
#
#             Violent Crimes in Last Month  Severe Crimes in Last Week  \
# Date
# 2015-03-09                           NaN                        1700
# 2015-03-10                           NaN                        1757
# 2015-03-11                           NaN                        1847
# 2015-03-12                           NaN                        1908
# 2015-03-13                           NaN                        1971
#
#             Severe Crimes in Last Month  Minor Crimes in Last Week  \
# Date
# 2015-03-09                          NaN                        418
# 2015-03-10                          NaN                        436
# 2015-03-11                          NaN                        459
# 2015-03-12                          NaN                        476
# 2015-03-13                          NaN                        466
#
#             Minor Crimes in Last Month  Petty Crimes in Last Week  \
# Date
# 2015-03-09                         NaN                        982
# 2015-03-10                         NaN                        996
# 2015-03-11                         NaN                       1032
# 2015-03-12                         NaN                       1029
# 2015-03-13                         NaN                       1012
#
#             Petty Crimes in Last Month
# Date
# 2015-03-09                         NaN
# 2015-03-10                         NaN
# 2015-03-11                         NaN
# 2015-03-12                         NaN
# 2015-03-13                         NaN

# %%
def get_days_by_area(timestamps):
    days_by_area = {}
    grouped = timestamps.groupby('Community Area')
    for name, frame in grouped:
        area_days = make_series_of_days_from_timestamps(frame, include_time_features=True)
        days_by_area[name] = area_days
    return days_by_area

# %%
days_by_area = get_days_by_area(timestamps)
# Out:
# -c:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
days_by_area['Edgewater'][-5:]
# Out:
#             Arrest  Domestic  Violent Crimes  Severe Crimes  Minor Crimes  \
# Date
# 2015-03-09       2         2               3              4             0
# 2015-03-10       3         1               2              4             1
# 2015-03-11       2         2               3              5             0
# 2015-03-12       2         1               2              0             2
# 2015-03-13       2         0               0              2             0
#
#             Petty Crimes Month Weekday  Violent Crimes in Last Week  \
# Date
# 2015-03-09             4     3       0                           11
# 2015-03-10             3     3       1                           11
# 2015-03-11             1     3       2                           13
# 2015-03-12             0     3       3                           14
# 2015-03-13             3     3       4                           12
#
#             Violent Crimes in Last Month  Severe Crimes in Last Week  \
# Date
# 2015-03-09                           NaN                          19
# 2015-03-10                           NaN                          20
# 2015-03-11                           NaN                          24
# 2015-03-12                           NaN                          20
# 2015-03-13                           NaN                          19
#
#             Severe Crimes in Last Month  Minor Crimes in Last Week  \
# Date
# 2015-03-09                          NaN                          2
# 2015-03-10                          NaN                          3
# 2015-03-11                          NaN                          3
# 2015-03-12                          NaN                          5
# 2015-03-13                          NaN                          4
#
#             Minor Crimes in Last Month  Petty Crimes in Last Week  \
# Date
# 2015-03-09                         NaN                          9
# 2015-03-10                         NaN                         11
# 2015-03-11                         NaN                         12
# 2015-03-12                         NaN                         11
# 2015-03-13                         NaN                         13
#
#             Petty Crimes in Last Month
# Date
# 2015-03-09                         NaN
# 2015-03-10                         NaN
# 2015-03-11                         NaN
# 2015-03-12                         NaN
# 2015-03-13                         NaN

# %%
def concat_areas_with_city(days_pan_city, days_by_area):
    new_column_names = ['Chicago ' + old_name for old_name in list(days_pan_city)]
    days_pan_city.columns = new_column_names
    concatenated_days_by_area = {}
    for area in days_by_area:
        area_days = days_by_area[area]
        concatenated_days_by_area[area] = area_days.join(days_pan_city)
    return concatenated_days_by_area

# %%
concatenated_days_by_area = concat_areas_with_city(days_pan_city, days_by_area)

# %%
concatenated_days_by_area['Edgewater']
# Out:
#             Arrest  Domestic  Violent Crimes  Severe Crimes  Minor Crimes  \
# Date
# 2015-02-26       1         1               2              2             1
# 2015-02-27       1         0               1              5             0
# 2015-02-28       2         0               0              1             1
# 2015-03-01       0         0               0              2             1
# 2015-03-02       1         0               0              3             0
# 2015-03-03       0         1               2              3             0
# 2015-03-04       0         1               1              1             0
# 2015-03-05       3         0               1              4             0
# 2015-03-06       0         1               2              3             1
# 2015-03-07       1         1               1              3             1
# 2015-03-08       0         0               1              1             0
# 2015-03-09       2         2               3              4             0
# 2015-03-10       3         1               2              4             1
# 2015-03-11       2         2               3              5             0
# 2015-03-12       2         1               2              0             2
# 2015-03-13       2         0               0              2             0
#
#             Petty Crimes Month Weekday  Violent Crimes in Last Week  \
# Date
# 2015-02-26             0     2       3                          NaN
# 2015-02-27             1     2       4                          NaN
# 2015-02-28             1     2       5                          NaN
# 2015-03-01             0     3       6                          NaN
# 2015-03-02             0     3       0                          NaN
# 2015-03-03             1     3       1                          NaN
# 2015-03-04             0     3       2                            6
# 2015-03-05             1     3       3                            5
# 2015-03-06             1     3       4                            6
# 2015-03-07             1     3       5                            7
# 2015-03-08             1     3       6                            8
# 2015-03-09             4     3       0                           11
# 2015-03-10             3     3       1                           11
# 2015-03-11             1     3       2                           13
# 2015-03-12             0     3       3                           14
# 2015-03-13             3     3       4                           12
#
#             Violent Crimes in Last Month                 ...                  \
# Date                                                     ...
# 2015-02-26                           NaN                 ...
# 2015-03-11                                  NaN
# 2015-03-12                                  NaN
# 2015-03-13                                  NaN
#
#             Chicago Minor Crimes in Last Week  \
# Date
# 2015-02-26                                NaN
# 2015-02-27                                NaN
# 2015-02-28                                NaN
# 2015-03-01                                NaN
# 2015-03-02                                NaN
# 2015-03-03                                NaN
# 2015-03-04                                408
# 2015-03-05                                410
# 2015-03-06                                414
# 2015-03-07                                418
# 2015-03-08                                411
# 2015-03-09                                418
# 2015-03-10                                436
# 2015-03-11                                459
# 2015-03-12                                476
# 2015-03-13                                466
#
#             Chicago Minor Crimes in Last Month  \
# Date
# 2015-02-26                                 NaN
# 2015-02-27                                 NaN
# 2015-02-28                                 NaN
# 2015-03-01                                 NaN
# 2015-03-02                                 NaN
# 2015-03-03                                 NaN
# 2015-03-04                                 NaN
# 2015-03-05                                 NaN
# 2015-03-06                                 NaN
# 2015-03-07                                 NaN
# 2015-03-08                                 NaN
# 2015-03-09                                 NaN
# 2015-03-10                                 NaN
# 2015-03-11                                 NaN
# 2015-03-12                                 NaN
# 2015-03-13                                 NaN
#
#             Chicago Petty Crimes in Last Week  \
# Date
# 2015-02-26                                NaN
# 2015-02-27                                NaN
# 2015-02-28                                NaN
# 2015-03-01                                NaN
# 2015-03-02                                NaN
# 2015-03-03                                NaN
# 2015-03-04                                884
# 2015-03-05                                931
# 2015-03-06                                949
# 2015-03-07                                987
# 2015-03-08                                983
# 2015-03-09                                982
# 2015-03-10                                996
# 2015-03-11                               1032
# 2015-03-12                               1029
# 2015-03-13                               1012
#
#             Chicago Petty Crimes in Last Month
# Date
# 2015-02-26                                 NaN
# 2015-02-27                                 NaN
# 2015-02-28                                 NaN
# 2015-03-01                                 NaN
# 2015-03-02                                 NaN
# 2015-03-03                                 NaN
# 2015-03-04                                 NaN
# 2015-03-05                                 NaN
# 2015-03-06                                 NaN
# 2015-03-07                                 NaN
# 2015-03-08                                 NaN
# 2015-03-09                                 NaN
# 2015-03-10                                 NaN
# 2015-03-11                                 NaN
# 2015-03-12                                 NaN
# 2015-03-13                                 NaN
#
# [16 rows x 30 columns]

# %%
def extract_features_from_data_frame(crimes_by_area):
    feature_vectors_by_area = {}
    for area in crimes_by_area:
        feature_vectors_by_area[area] = crimes_by_area[area].values
    return feature_vectors_by_area

# %%
concatenated_days_by_area = extract_features_from_data_frame(concatenated_days_by_area)

# %%
concatenated_days_by_area['Edgewater']
# Out:
# array([[1.0, 1.0, 2, 2, 1, 0, 2, 3, nan, nan, nan, nan, nan, nan, nan, nan,
#         145.0, 57.0, 109, 187, 58, 104, nan, nan, nan, nan, nan, nan, nan,
#         nan],
#        [1.0, 0.0, 1, 5, 0, 1, 2, 4, nan, nan, nan, nan, nan, nan, nan, nan,
#         185.0, 87.0, 148, 245, 81, 141, nan, nan, nan, nan, nan, nan, nan,
#         nan],
#        [2.0, 0.0, 0, 1, 1, 1, 2, 5, nan, nan, nan, nan, nan, nan, nan, nan,
#         156.0, 99.0, 150, 209, 55, 109, nan, nan, nan, nan, nan, nan, nan,
#         nan],
